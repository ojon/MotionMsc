# %% [markdown]
# # Funções e scripts utilizados no mestrado
#
#
# autor: João Oda
#
# bibliotecas necessárias:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
import sys
import string
import Levenshtein as l
import itertools
import scipy.io
import pandas as pd

sys.path.insert(1, r'./functions')  # add dir to pythonpath
from detect_peaks import detect_peaks

# %% [markdown]
# ## Intervalos de ativação articular monotônica
#
# A função genIAAM particiona o intervalo de tempo do movimento, em sub intervalos com a propriedade de ativação monotônica.
#
# Inicialmente para o sinal correspondente a cada DOF, é realizada: -detecção de picos e vales. -remoção de pontos correspondentes a variações de amplitudes muito pequenas em sequência.
#
# Depois após a união dos pontos dos multiplos sinais, são removidos pontos correspondentes a instântes muito próximos.

# %%
def gen_iaam(data, jointdofset,
             minpeakdist=5,
             minpeakheight=-180,
             amplimjoint=15,
             simult_lim=5,
             display=False):
    """ determina os ponto de particão do intervalo em
    subintervalos IAAM

        Parameters
        ----------
        data : ndarray, uma coluna para cada DOF, uma linha para cada
        frame, dtype indicando os labels

        jointdofset : list, uma lista com os labels dos DOF de interesse

        minpeakheight : {None, number}, optional (default = -180
            A etapa de detecção de picos, se restringe a picos maiores
            que minpeakheight

        minpeakdist : positive integer, optional (default = 5
            A etapa de detecção de picos, se restringe a picos que estão
            separados de pelo menos minPeakDistance amostras

        amplimjoint : positive number, optional (default = 15)
            Entre dois pontos de partição a diferença de amplitude é de
            pelo menos amplimjoint

        simult_lim: = positive number, optional (default = 3)
            Pontos que ocorrem em instântes a menos de 3 frames de diferença
            são considerados simultanêos e somente o primeiro é considerado

        display: bool, optional (default = False)
            if True (1), plot data in matplotlib figure.

        Returns
        -------
        ind : 1D array_like
            indices dos pontos de partição do intervalo
    """

    multsigpoints = np.array([], dtype='int64')

    if display:
        plt.subplots(1, sharex=True, figsize=(6, 6))

    for dof in jointdofset:
        curve = data[dof]
        valleys = detect_peaks(curve, mph=minpeakheight, mpd=minpeakdist, valley=True, edge='both')
        peaks = detect_peaks(curve, mph=minpeakheight, mpd=minpeakdist, edge='both')
        peaksandvalleys = np.union1d(valleys, peaks)
        peaksandvalleys = np.insert(peaksandvalleys, [0], 0)
        peaksandvalleys = np.append(peaksandvalleys, [curve.size - 1])

        ampsignalpoints = np.array([], dtype='int64')
        first = peaksandvalleys[0]
        second = peaksandvalleys[1]
        for val in peaksandvalleys[2::]:
            third = val
            v1 = curve[first]
            v2 = curve[second]
            v3 = curve[third]
            if (np.abs(v1 - v2) > amplimjoint) or (np.abs(v2 - v3) > amplimjoint):
                ampsignalpoints = np.append(ampsignalpoints, second)
            first = second
            second = third

        ampsignalpoints = np.insert(ampsignalpoints, 0, 0)
        ampsignalpoints = np.append(ampsignalpoints, curve.size - 1)
        multsigpoints = np.union1d(multsigpoints, ampsignalpoints)
        nframes = np.shape(data)[0]
        frames = np.linspace(1, nframes, nframes)
        if display:
            plt.plot(frames, curve, label=dof, lw=1)
            plt.plot(frames[ampsignalpoints], curve[ampsignalpoints], 'bo')
            plt.plot(frames[peaksandvalleys], curve[peaksandvalleys], 'rx')

    partitionpoints = np.array([multsigpoints[0]], dtype='int64')

    for sigPoint in multsigpoints[1::]:
        if (sigPoint - partitionpoints[-1]) > simult_lim:
            partitionpoints = np.append(partitionpoints, sigPoint)

    if display:
        for finalSeg in partitionpoints:
            plt.axvline(x=finalSeg, ls='--')
        plt.legend(fontsize='medium')
        plt.xlabel('frames', fontsize=16)
        plt.ylabel('angulo articular(graus)', fontsize=16)
        # plt.ylim((-40, 90))
        #plt.show()

    return partitionpoints

# %%
fileList = glob.glob("./cleanNpyData/*walk2StepsLstart*")
data = np.load(fileList[1])
dofs = [
    'rhipjoint__rfemur_rx',  #hip
    'rfemur__rtibia_rx',  #knee
    'rtibia__rfoot_rx',  #ankle
    
]
partitionP = gen_iaam(data,dofs,display = True)

# %% [markdown]
# ## Motion Word
#
# ### Algumas funções auxiliares:
# A função cInt2cChar converte um inteiro para um correspondente char, de acordo com a convenção de alfabeto adota.

# %%
def cInt2cChar(x):
    return chr(64+x)

# %% [markdown]
# A função int2base converte um inteiro para uma representação em outra base.

# %%
def int2base(x, base):
    digs = string.digits + string.ascii_letters
    if x < 0:
        sign = -1
    elif x == 0:
        return digs[0]
    else:
        sign = 1
    x *= sign
    digits = []
    while x:
        index = x % base
        digits.append(digs[index])
        x //= base
    if sign < 0:
        digits.append('-')
    digits.reverse()
    return ''.join(digits)

# %% [markdown]
# ### Função que gera uma motion word
#
# A função gen_motion_word_int recebe como entrada os dados, o conjunto de graus de liberdade das articulações a serem utilizadas para gerar a Motion Word e o parâmetro varLevel, que corresponde a minima magnitude da velocidade angular média(graus por segundo) para que seja considerada uma variação.

# %%
def gen_motion_word_int(data, joint_dof_set, var_levels, amp_lim_joint=5,
                        display=False, symb = True):
    """
    :param amp_lim_joint:
    :param data: ndarray, uma coluna para cada DOF, uma linha para cada
           frame, dtype indicando os labels

    :param joint_dof_set: list, uma lista com os labels dos DOF de interesse, no máximo

    :param var_level: positive integer, optional (default = 10)
           calculamos a velocidade angular média(graus/segundos) no intervalo e comparamos
           com varLevel para determinar o estado do IAAM

    :param display: bool, optional (default = False)
            if True (1), plot data in matplotlib figure.

    :return: partition_points: 1D array_like
            indices dos pontos de partição do intervalo

    :return: motionWordInt: 1D array_like
            sequência de número correspondente a motion word

    """
    partition_points = gen_iaam(data, joint_dof_set, amplimjoint=amp_lim_joint,
                                display=display)
    motion_word_int = np.array([], dtype=int)
    pseg = 0
    for point in partition_points[1:]:
        symbol = 0;
        dofIndex = 0;
        for dof in joint_dof_set[::-1]:
            curve = data[dof]
            diff = curve[point] - curve[pseg]
            slope = diff * 120 / (1.0 * point - pseg)
            if np.abs(slope) > var_levels[dof]:
                if diff > 0:
                    symbol += 2 * (3 ** dofIndex)
                else:
                    symbol += 1 * (3 ** dofIndex)
            dofIndex += 1
        motion_word_int = np.append(motion_word_int, int(symbol))
        pseg = point
    labels_points = partition_points[0:-1] + (partition_points[1::] - partition_points[0:-1]) / 2.0
    mw_b3 = [int2base(c, 3) for c in motion_word_int]
    if display:
        for symb_int, symb_b3, lp in zip(motion_word_int, mw_b3, labels_points):
            if symb == True:
                plt.text(lp - 2, 55, cInt2cChar(symb_int), fontsize=14, color='purple')
            else:
                plt.text(lp - 4, 40, symb_int, fontsize=10, color='purple')
            #plt.text(lp - 2, 55, symb_b3, fontsize=14, color='purple')
        plt.show()
    return partition_points, motion_word_int

# %% [markdown]
# ### Exemplo

# %%
fileList = glob.glob("./cleanNpyData/*walk2StepsLstart*")
data = np.load(fileList[1])
dofs = [
    'rhipjoint__rfemur_rx',  #hip
    'rfemur__rtibia_rx',  #knee
    'rtibia__rfoot_rx',  #ankle
    #'lclavicle__lhumerus_rx'
]
var_levels = {
    'rhipjoint__rfemur_rx': 30,
    'rfemur__rtibia_rx': 25,
    'rtibia__rfoot_rx': 10,
    #'lclavicle__lhumerus_rx': 30
}

# %%
[p, w] = gen_motion_word_int(data, dofs, var_levels, display = True, symb=True)

# %% [markdown]
# representação em base 3

# %%
[int2base(c,3) for c in w]
# Out:
# ['212', '122', '121', '111', '112', '22', '221', '211', '201']

# %% [markdown]
# representação  com letras do alfato romano e o simbolo @

# %%
''.join([cInt2cChar(c) for c in w])
# Out:
# 'WQPMNHYVS'

# %% [markdown]
# representação por inteiros

# %%
print(w)
# Out:
# [23 17 16 13 14  8 25 22 19]

# %% [markdown]
# ## Similaridade de Movimentos

# %%
motion1 = np.load(fileList[0])
motion2 = np.load(fileList[8])

# %%
[p1, w1] = gen_motion_word_int(motion1, dofs, var_levels,  display = True)
[p2, w2] = gen_motion_word_int(motion2, dofs, var_levels,  display = True)
mw1 = ''.join([cInt2cChar(c) for c in w1])
mw2 = ''.join([cInt2cChar(c) for c in w2])

# %%
print(mw1)
print(mw2)
# Out:
# VWQPMHYS
# VWTQPMHYV

# %% [markdown]
# distância de Levenstain

# %%
l.distance(mw1,mw2)
# Out:
# 2

# %% [markdown]
# operações para transformar mw1 em mw2:

# %%
l.editops(mw1,mw2)
# Out:
# [('insert', 2, 2), ('replace', 7, 8)]

# %% [markdown]
# insira o char na pos 2 de mw2 na pos 2 de mw1: T -> W_P
#
# substitua o char na pos 7 de mw1 pelo char da pos 8 de mw2: S <-> V

# %% [markdown]
# ## Matriz de distâncias
#
# todos os movimentos

# %%
allMotions = [
    'depositFloorR',
    'depositLowR',
    'elbowToKnee1RepsLelbowStart',
    'hopBothLegs1hops',
    'hopRLeg1hops',
    'jogOnPlaceStartAir2StepsLStart',
    'jumpDown',
    'jumpingJack1Reps',
    'kickRFront1Reps',
    'kickRSide1Reps',
    'lieDownFloor',
    'shuffle2StepsRStart',
    'sitDownChair',
    'sitDownFloor',
    'sitDownKneelTieShoes',
    'sitDownTable',
    'skier1RepsLstart',
    'squat1Reps',
    'standUpLieFloor',
    'standUpSitChair',
    'standUpSitFloor',
    'walk2StepsLstart',
    'walkBackwards2StepsRstart',
    'walkLeft2Steps',
    'walkRightCrossFront3Steps'
]
motionsDic = dict(zip(allMotions, np.arange(1, np.size(allMotions) + 1)))

# %% [markdown]
# movimentos selecionados

# %%
motionList = [allMotions[3 - 1],
              allMotions[6 - 1],
              allMotions[12 - 1],             
              allMotions[15 - 1],
              allMotions[16 - 1],
              allMotions[17 - 1],
              allMotions[18 - 1],
              allMotions[20 - 1],
              allMotions[22 - 1],
              allMotions[23 - 1],
              ]

# %%
selMotions = motionList
np.size(selMotions)
# Out:
# 10

# %%
selDofs = [
    'rhipjoint__rfemur_rx',  # hip
    'rfemur__rtibia_rx',  # knee
    'rtibia__rfoot_rx',  # ankle
    #'lclavicle__lhumerus_rx',  # shoulder
]

# %% [markdown]
# calculando as motion words para cada movimento e gerando a matriz de distâncias, exportando o resultado em arquivos .mat

# %%
labelSet = []
motionFiles = []
enumClasses = []
enumClassIndex = 1

for motion in selMotions:
    currentMoveFileList = glob.glob("./cleanNpyData/*" + motion + "*")
    currentLabels = [motion] * np.size(currentMoveFileList)
    currentEnumClass = [motionsDic[motion]] * np.size(currentMoveFileList)
    enumClassIndex += 1
    labelSet = labelSet + currentLabels
    motionFiles = motionFiles + currentMoveFileList
    enumClasses = enumClasses + currentEnumClass

wList = []
labels = []
completeLabels = []
fileLabels = []
labelIndex = 0
for file in motionFiles:
    data = np.load(file)
    [pIndex, wInt] = gen_motion_word_int(data, selDofs, var_levels, amp_lim_joint=5)
    wChar = ''.join([cInt2cChar(cInt) for cInt in wInt])    
    wList.append(wChar)
    label = labelSet[labelIndex]
    labelIndex += 1
    completeLabels.append(label + '_' + wChar)
    fileLabels.append(file[19:-8])
distM = []
for w1 in wList:
    row = []
    for w2 in wList:
        row.append(l.distance(w1, w2))
    distM.append(row)

dataId = '_'.join(str(e) for e in list(set(enumClasses)))
scipy.io.savemat('distM_' + dataId + '.mat', mdict={'distM': np.array(distM)})
scipy.io.savemat('fullLabels_' + dataId + '.mat', mdict={'full_labels': np.array(completeLabels)})
scipy.io.savemat('labels_' + dataId + '.mat', mdict={'labels': labelSet})
scipy.io.savemat('enumClasses_' + dataId + '.mat', mdict={'enumClasses': enumClasses})
scipy.io.savemat('fileLabels_' + dataId + '.mat', mdict={'fileLabels': fileLabels})

# %%
set(labelSet)
# Out:
# {'elbowToKnee1RepsLelbowStart',
#  'jogOnPlaceStartAir2StepsLStart',
#  'shuffle2StepsRStart',
#  'sitDownKneelTieShoes',
#  'sitDownTable',
#  'skier1RepsLstart',
#  'squat1Reps',
#  'standUpSitChair',
#  'walk2StepsLstart',
#  'walkBackwards2StepsRstart'}

# %%
pd.DataFrame(distM, columns=completeLabels, index=completeLabels)
# Out:
#                                             elbowToKnee1RepsLelbowStart_OIKTWV  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                           0
# elbowToKnee1RepsLelbowStart_QPQWWV                                           4
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                         5
# elbowToKnee1RepsLelbowStart_QPIRWV                                           4
# elbowToKnee1RepsLelbowStart_QO@WUVD                                          6
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                         5
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                        7
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                         7
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                         6
# elbowToKnee1RepsLelbowStart_QPQBWV                                           4
# elbowToKnee1RepsLelbowStart_QPQWUV                                           5
# elbowToKnee1RepsLelbowStart_BQOWVG                                           5
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                         6
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                        7
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                      7
# elbowToKnee1RepsLelbowStart_QPPMVWV                                          5
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                         6
# elbowToKnee1RepsLelbowStart_QPQAWV                                           4
# elbowToKnee1RepsLelbowStart_QOITUVT                                          4
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                         4
# elbowToKnee1RepsLelbowStart_QONEVV                                           5
# elbowToKnee1RepsLelbowStart_QPUWV                                            4
# elbowToKnee1RepsLelbowStart_QOWV                                             4
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                        7
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                      9
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                        8
# elbowToKnee1RepsLelbowStart_QPWUV                                            5
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                      7
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                       7
# jogOnPlaceStartAir2StepsLStart_VKQOV                                         4
# ...                                                                        ...
# walk2StepsLstart_WQPMNHYS                                                    8
# walk2StepsLstart_WTQPMZYS                                                    8
# walk2StepsLstart_VWZQPMDHSS                                                 10
# walk2StepsLstart_WTQPMHSV                                                    7
# walk2StepsLstart_VWQPMDHSAG@                                                11
# walk2StepsLstart_WTQPMZV                                                     6
# walk2StepsLstart_WQPMZYV                                                     6
# walk2StepsLstart_VXQPMDZS                                                    8
# walk2StepsLstart_VXQPMZSS                                                    8
# walk2StepsLstart_WTQPMJZYS                                                   9
# walk2StepsLstart_WQPMCHSS                                                    8
# walk2StepsLstart_VWQPMZS                                                     7
# walk2StepsLstart_VWOQPMDZS                                                   8
# walk2StepsLstart_UWQPMLHYVV                                                  9
# walk2StepsLstart_UWZQPMNHHYSA                                               12
# walkBackwards2StepsRstart_QZRVAKMH                                           8
# walkBackwards2StepsRstart_WVMIQKMDHX                                         8
# walkBackwards2StepsRstart_QGZWVPQKDZX                                       10
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                     12
# walkBackwards2StepsRstart_FHWVJKKJAZ                                         9
# walkBackwards2StepsRstart_IXWVDKJGX                                          8
# walkBackwards2StepsRstart_OZUVKJMBHX                                         8
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                  14
# walkBackwards2StepsRstart_BOZWVDKJG                                          8
# walkBackwards2StepsRstart_OZWVJKJGG                                          7
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                    11
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                      10
# walkBackwards2StepsRstart_GZUDBKQNGZ                                         9
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                       10
# walkBackwards2StepsRstart_PHZWVDKNGGX                                       10
#
#                                             elbowToKnee1RepsLelbowStart_QPQWWV  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                           4
# elbowToKnee1RepsLelbowStart_QPQWWV                                           0
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                         4
# elbowToKnee1RepsLelbowStart_QPIRWV                                           2
# elbowToKnee1RepsLelbowStart_QO@WUVD                                          4
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                         4
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                        7
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                         6
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                         4
# elbowToKnee1RepsLelbowStart_QPQBWV                                           1
# elbowToKnee1RepsLelbowStart_QPQWUV                                           1
# elbowToKnee1RepsLelbowStart_BQOWVG                                           4
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                         3
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                        6
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                      8
# elbowToKnee1RepsLelbowStart_QPPMVWV                                          3
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                         3
# elbowToKnee1RepsLelbowStart_QPQAWV                                           1
# elbowToKnee1RepsLelbowStart_QOITUVT                                          5
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                         6
# elbowToKnee1RepsLelbowStart_QONEVV                                           4
# elbowToKnee1RepsLelbowStart_QPUWV                                            2
# elbowToKnee1RepsLelbowStart_QOWV                                             3
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                        4
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                      7
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                        7
# elbowToKnee1RepsLelbowStart_QPWUV                                            2
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                      7
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                       7
# jogOnPlaceStartAir2StepsLStart_VKQOV                                         4
# ...                                                                        ...
# walk2StepsLstart_WQPMNHYS                                                    6
# walk2StepsLstart_WTQPMZYS                                                    6
# walk2StepsLstart_VWZQPMDHSS                                                  8
# walk2StepsLstart_WTQPMHSV                                                    5
# walk2StepsLstart_VWQPMDHSAG@                                                 9
# walk2StepsLstart_WTQPMZV                                                     5
# walk2StepsLstart_WQPMZYV                                                     4
# walk2StepsLstart_VXQPMDZS                                                    6
# walk2StepsLstart_VXQPMZSS                                                    6
# walk2StepsLstart_WTQPMJZYS                                                   7
# walk2StepsLstart_WQPMCHSS                                                    6
# walk2StepsLstart_VWQPMZS                                                     6
# walk2StepsLstart_VWOQPMDZS                                                   7
# walk2StepsLstart_UWQPMLHYVV                                                  7
# walk2StepsLstart_UWZQPMNHHYSA                                               10
# walkBackwards2StepsRstart_QZRVAKMH                                           7
# walkBackwards2StepsRstart_WVMIQKMDHX                                         9
# walkBackwards2StepsRstart_QGZWVPQKDZX                                        8
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                     10
# walkBackwards2StepsRstart_FHWVJKKJAZ                                        10
# walkBackwards2StepsRstart_IXWVDKJGX                                          9
# walkBackwards2StepsRstart_OZUVKJMBHX                                        10
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                  14
# walkBackwards2StepsRstart_BOZWVDKJG                                          8
# walkBackwards2StepsRstart_OZWVJKJGG                                          9
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                    11
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                      10
# walkBackwards2StepsRstart_GZUDBKQNGZ                                         9
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                        8
# walkBackwards2StepsRstart_PHZWVDKNGGX                                        9
#
#                                             elbowToKnee1RepsLelbowStart_QPO@AVWV  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                             5
# elbowToKnee1RepsLelbowStart_QPQWWV                                             4
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                           0
# elbowToKnee1RepsLelbowStart_QPIRWV                                             4
# elbowToKnee1RepsLelbowStart_QO@WUVD                                            5
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                           4
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                          7
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                           7
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                           3
# elbowToKnee1RepsLelbowStart_QPQBWV                                             4
# elbowToKnee1RepsLelbowStart_QPQWUV                                             5
# elbowToKnee1RepsLelbowStart_BQOWVG                                             6
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                           3
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                          3
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                        7
# elbowToKnee1RepsLelbowStart_QPPMVWV                                            3
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                           3
# elbowToKnee1RepsLelbowStart_QPQAWV                                             3
# elbowToKnee1RepsLelbowStart_QOITUVT                                            6
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                           7
# elbowToKnee1RepsLelbowStart_QONEVV                                             4
# elbowToKnee1RepsLelbowStart_QPUWV                                              4
# elbowToKnee1RepsLelbowStart_QOWV                                               4
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                          5
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                        7
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                          7
# elbowToKnee1RepsLelbowStart_QPWUV                                              5
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                        8
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                         7
# jogOnPlaceStartAir2StepsLStart_VKQOV                                           7
# ...                                                                          ...
# walk2StepsLstart_WQPMNHYS                                                      7
# walk2StepsLstart_WTQPMZYS                                                      8
# walk2StepsLstart_VWZQPMDHSS                                                    9
# walk2StepsLstart_WTQPMHSV                                                      7
# walk2StepsLstart_VWQPMDHSAG@                                                   9
# walk2StepsLstart_WTQPMZV                                                       7
# walk2StepsLstart_WQPMZYV                                                       6
# walk2StepsLstart_VXQPMDZS                                                      8
# walk2StepsLstart_VXQPMZSS                                                      8
# walk2StepsLstart_WTQPMJZYS                                                     8
# walk2StepsLstart_WQPMCHSS                                                      7
# walk2StepsLstart_VWQPMZS                                                       8
# walk2StepsLstart_VWOQPMDZS                                                     8
# walk2StepsLstart_UWQPMLHYVV                                                    7
# walk2StepsLstart_UWZQPMNHHYSA                                                 10
# walkBackwards2StepsRstart_QZRVAKMH                                             6
# walkBackwards2StepsRstart_WVMIQKMDHX                                          10
# walkBackwards2StepsRstart_QGZWVPQKDZX                                         10
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                       11
# walkBackwards2StepsRstart_FHWVJKKJAZ                                          10
# walkBackwards2StepsRstart_IXWVDKJGX                                            9
# walkBackwards2StepsRstart_OZUVKJMBHX                                          10
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                    15
# walkBackwards2StepsRstart_BOZWVDKJG                                            8
# walkBackwards2StepsRstart_OZWVJKJGG                                            9
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                      12
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                        11
# walkBackwards2StepsRstart_GZUDBKQNGZ                                          10
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                         10
# walkBackwards2StepsRstart_PHZWVDKNGGX                                         10
#
#                                             elbowToKnee1RepsLelbowStart_QPIRWV  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                           4
# elbowToKnee1RepsLelbowStart_QPQWWV                                           2
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                         4
# elbowToKnee1RepsLelbowStart_QPIRWV                                           0
# elbowToKnee1RepsLelbowStart_QO@WUVD                                          5
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                         2
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                        7
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                         6
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                         4
# elbowToKnee1RepsLelbowStart_QPQBWV                                           2
# elbowToKnee1RepsLelbowStart_QPQWUV                                           3
# elbowToKnee1RepsLelbowStart_BQOWVG                                           5
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                         4
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                        5
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                      8
# elbowToKnee1RepsLelbowStart_QPPMVWV                                          3
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                         4
# elbowToKnee1RepsLelbowStart_QPQAWV                                           2
# elbowToKnee1RepsLelbowStart_QOITUVT                                          4
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                         6
# elbowToKnee1RepsLelbowStart_QONEVV                                           4
# elbowToKnee1RepsLelbowStart_QPUWV                                            2
# elbowToKnee1RepsLelbowStart_QOWV                                             3
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                        5
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                      8
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                        7
# elbowToKnee1RepsLelbowStart_QPWUV                                            3
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                      7
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                       7
# jogOnPlaceStartAir2StepsLStart_VKQOV                                         5
# ...                                                                        ...
# walk2StepsLstart_WQPMNHYS                                                    6
# walk2StepsLstart_WTQPMZYS                                                    6
# walk2StepsLstart_VWZQPMDHSS                                                  8
# walk2StepsLstart_WTQPMHSV                                                    5
# walk2StepsLstart_VWQPMDHSAG@                                                 9
# walk2StepsLstart_WTQPMZV                                                     5
# walk2StepsLstart_WQPMZYV                                                     4
# walk2StepsLstart_VXQPMDZS                                                    6
# walk2StepsLstart_VXQPMZSS                                                    6
# walk2StepsLstart_WTQPMJZYS                                                   7
# walk2StepsLstart_WQPMCHSS                                                    6
# walk2StepsLstart_VWQPMZS                                                     6
# walk2StepsLstart_VWOQPMDZS                                                   7
# walk2StepsLstart_UWQPMLHYVV                                                  7
# walk2StepsLstart_UWZQPMNHHYSA                                               10
# walkBackwards2StepsRstart_QZRVAKMH                                           7
# walkBackwards2StepsRstart_WVMIQKMDHX                                         9
# walkBackwards2StepsRstart_QGZWVPQKDZX                                        9
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                     10
# walkBackwards2StepsRstart_FHWVJKKJAZ                                        10
# walkBackwards2StepsRstart_IXWVDKJGX                                          8
# walkBackwards2StepsRstart_OZUVKJMBHX                                        10
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                  14
# walkBackwards2StepsRstart_BOZWVDKJG                                          8
# walkBackwards2StepsRstart_OZWVJKJGG                                          9
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                    12
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                      10
# walkBackwards2StepsRstart_GZUDBKQNGZ                                        10
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                        9
# walkBackwards2StepsRstart_PHZWVDKNGGX                                        9
#
#                                             elbowToKnee1RepsLelbowStart_QO@WUVD  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                            6
# elbowToKnee1RepsLelbowStart_QPQWWV                                            4
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                          5
# elbowToKnee1RepsLelbowStart_QPIRWV                                            5
# elbowToKnee1RepsLelbowStart_QO@WUVD                                           0
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                          6
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                         5
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                          7
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                          5
# elbowToKnee1RepsLelbowStart_QPQBWV                                            5
# elbowToKnee1RepsLelbowStart_QPQWUV                                            3
# elbowToKnee1RepsLelbowStart_BQOWVG                                            4
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                          6
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                         5
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                       8
# elbowToKnee1RepsLelbowStart_QPPMVWV                                           6
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                          6
# elbowToKnee1RepsLelbowStart_QPQAWV                                            5
# elbowToKnee1RepsLelbowStart_QOITUVT                                           3
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                          6
# elbowToKnee1RepsLelbowStart_QONEVV                                            4
# elbowToKnee1RepsLelbowStart_QPUWV                                             4
# elbowToKnee1RepsLelbowStart_QOWV                                              3
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                         6
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                       8
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                         7
# elbowToKnee1RepsLelbowStart_QPWUV                                             3
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                       7
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                        7
# jogOnPlaceStartAir2StepsLStart_VKQOV                                          6
# ...                                                                         ...
# walk2StepsLstart_WQPMNHYS                                                     7
# walk2StepsLstart_WTQPMZYS                                                     8
# walk2StepsLstart_VWZQPMDHSS                                                   9
# walk2StepsLstart_WTQPMHSV                                                     7
# walk2StepsLstart_VWQPMDHSAG@                                                 10
# walk2StepsLstart_WTQPMZV                                                      7
# walk2StepsLstart_WQPMZYV                                                      6
# walk2StepsLstart_VXQPMDZS                                                     8
# walk2StepsLstart_VXQPMZSS                                                     8
# walk2StepsLstart_WTQPMJZYS                                                    8
# walk2StepsLstart_WQPMCHSS                                                     7
# walk2StepsLstart_VWQPMZS                                                      7
# walk2StepsLstart_VWOQPMDZS                                                    8
# walk2StepsLstart_UWQPMLHYVV                                                   8
# walk2StepsLstart_UWZQPMNHHYSA                                                11
# walkBackwards2StepsRstart_QZRVAKMH                                            7
# walkBackwards2StepsRstart_WVMIQKMDHX                                          9
# walkBackwards2StepsRstart_QGZWVPQKDZX                                         8
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                      10
# walkBackwards2StepsRstart_FHWVJKKJAZ                                         10
# walkBackwards2StepsRstart_IXWVDKJGX                                           8
# walkBackwards2StepsRstart_OZUVKJMBHX                                          9
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                   14
# walkBackwards2StepsRstart_BOZWVDKJG                                           6
# walkBackwards2StepsRstart_OZWVJKJGG                                           8
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                     11
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                       11
# walkBackwards2StepsRstart_GZUDBKQNGZ                                         10
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                         8
# walkBackwards2StepsRstart_PHZWVDKNGGX                                         9
#
#                                             elbowToKnee1RepsLelbowStart_QPIN@RWV  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                             5
# elbowToKnee1RepsLelbowStart_QPQWWV                                             4
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                           4
# elbowToKnee1RepsLelbowStart_QPIRWV                                             2
# elbowToKnee1RepsLelbowStart_QO@WUVD                                            6
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                           0
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                          8
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                           7
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                           5
# elbowToKnee1RepsLelbowStart_QPQBWV                                             4
# elbowToKnee1RepsLelbowStart_QPQWUV                                             5
# elbowToKnee1RepsLelbowStart_BQOWVG                                             7
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                           3
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                          4
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                        8
# elbowToKnee1RepsLelbowStart_QPPMVWV                                            4
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                           4
# elbowToKnee1RepsLelbowStart_QPQAWV                                             4
# elbowToKnee1RepsLelbowStart_QOITUVT                                            6
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                           8
# elbowToKnee1RepsLelbowStart_QONEVV                                             5
# elbowToKnee1RepsLelbowStart_QPUWV                                              4
# elbowToKnee1RepsLelbowStart_QOWV                                               5
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                          6
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                        8
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                          8
# elbowToKnee1RepsLelbowStart_QPWUV                                              5
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                        8
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                         6
# jogOnPlaceStartAir2StepsLStart_VKQOV                                           7
# ...                                                                          ...
# walk2StepsLstart_WQPMNHYS                                                      6
# walk2StepsLstart_WTQPMZYS                                                      8
# walk2StepsLstart_VWZQPMDHSS                                                    9
# walk2StepsLstart_WTQPMHSV                                                      7
# walk2StepsLstart_VWQPMDHSAG@                                                   9
# walk2StepsLstart_WTQPMZV                                                       7
# walk2StepsLstart_WQPMZYV                                                       6
# walk2StepsLstart_VXQPMDZS                                                      8
# walk2StepsLstart_VXQPMZSS                                                      8
# walk2StepsLstart_WTQPMJZYS                                                     8
# walk2StepsLstart_WQPMCHSS                                                      7
# walk2StepsLstart_VWQPMZS                                                       8
# walk2StepsLstart_VWOQPMDZS                                                     9
# walk2StepsLstart_UWQPMLHYVV                                                    7
# walk2StepsLstart_UWZQPMNHHYSA                                                  9
# walkBackwards2StepsRstart_QZRVAKMH                                             7
# walkBackwards2StepsRstart_WVMIQKMDHX                                           9
# walkBackwards2StepsRstart_QGZWVPQKDZX                                         10
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                       11
# walkBackwards2StepsRstart_FHWVJKKJAZ                                          10
# walkBackwards2StepsRstart_IXWVDKJGX                                            9
# walkBackwards2StepsRstart_OZUVKJMBHX                                          10
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                    16
# walkBackwards2StepsRstart_BOZWVDKJG                                            9
# walkBackwards2StepsRstart_OZWVJKJGG                                            9
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                      13
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                        11
# walkBackwards2StepsRstart_GZUDBKQNGZ                                          10
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                         10
# walkBackwards2StepsRstart_PHZWVDKNGGX                                         11
#
#                                             elbowToKnee1RepsLelbowStart_@AQOIUVDN  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                              7
# elbowToKnee1RepsLelbowStart_QPQWWV                                              7
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                            7
# elbowToKnee1RepsLelbowStart_QPIRWV                                              7
# elbowToKnee1RepsLelbowStart_QO@WUVD                                             5
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                            8
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                           0
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                            6
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                            8
# elbowToKnee1RepsLelbowStart_QPQBWV                                              7
# elbowToKnee1RepsLelbowStart_QPQWUV                                              6
# elbowToKnee1RepsLelbowStart_BQOWVG                                              6
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                            7
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                           8
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                         7
# elbowToKnee1RepsLelbowStart_QPPMVWV                                             7
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                            7
# elbowToKnee1RepsLelbowStart_QPQAWV                                              7
# elbowToKnee1RepsLelbowStart_QOITUVT                                             5
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                            8
# elbowToKnee1RepsLelbowStart_QONEVV                                              6
# elbowToKnee1RepsLelbowStart_QPUWV                                               7
# elbowToKnee1RepsLelbowStart_QOWV                                                6
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                           7
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                         8
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                           6
# elbowToKnee1RepsLelbowStart_QPWUV                                               6
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                         9
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                          9
# jogOnPlaceStartAir2StepsLStart_VKQOV                                            6
# ...                                                                           ...
# walk2StepsLstart_WQPMNHYS                                                       8
# walk2StepsLstart_WTQPMZYS                                                       8
# walk2StepsLstart_VWZQPMDHSS                                                     9
# walk2StepsLstart_WTQPMHSV                                                       8
# walk2StepsLstart_VWQPMDHSAG@                                                   10
# walk2StepsLstart_WTQPMZV                                                        7
# walk2StepsLstart_WQPMZYV                                                        8
# walk2StepsLstart_VXQPMDZS                                                       8
# walk2StepsLstart_VXQPMZSS                                                       8
# walk2StepsLstart_WTQPMJZYS                                                      8
# walk2StepsLstart_WQPMCHSS                                                       8
# walk2StepsLstart_VWQPMZS                                                        8
# walk2StepsLstart_VWOQPMDZS                                                      8
# walk2StepsLstart_UWQPMLHYVV                                                     9
# walk2StepsLstart_UWZQPMNHHYSA                                                  11
# walkBackwards2StepsRstart_QZRVAKMH                                              9
# walkBackwards2StepsRstart_WVMIQKMDHX                                            9
# walkBackwards2StepsRstart_QGZWVPQKDZX                                          10
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                        11
# walkBackwards2StepsRstart_FHWVJKKJAZ                                           10
# walkBackwards2StepsRstart_IXWVDKJGX                                             9
# walkBackwards2StepsRstart_OZUVKJMBHX                                           10
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                     15
# walkBackwards2StepsRstart_BOZWVDKJG                                             8
# walkBackwards2StepsRstart_OZWVJKJGG                                             9
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                       10
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                         12
# walkBackwards2StepsRstart_GZUDBKQNGZ                                           10
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                          10
# walkBackwards2StepsRstart_PHZWVDKNGGX                                          10
#
#                                             elbowToKnee1RepsLelbowStart_AAQQOKBV  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                             7
# elbowToKnee1RepsLelbowStart_QPQWWV                                             6
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                           7
# elbowToKnee1RepsLelbowStart_QPIRWV                                             6
# elbowToKnee1RepsLelbowStart_QO@WUVD                                            7
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                           7
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                          6
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                           0
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                           7
# elbowToKnee1RepsLelbowStart_QPQBWV                                             6
# elbowToKnee1RepsLelbowStart_QPQWUV                                             6
# elbowToKnee1RepsLelbowStart_BQOWVG                                             6
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                           6
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                          7
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                        6
# elbowToKnee1RepsLelbowStart_QPPMVWV                                            7
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                           6
# elbowToKnee1RepsLelbowStart_QPQAWV                                             6
# elbowToKnee1RepsLelbowStart_QOITUVT                                            7
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                           8
# elbowToKnee1RepsLelbowStart_QONEVV                                             6
# elbowToKnee1RepsLelbowStart_QPUWV                                              6
# elbowToKnee1RepsLelbowStart_QOWV                                               5
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                          5
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                        9
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                          6
# elbowToKnee1RepsLelbowStart_QPWUV                                              6
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                        8
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                         8
# jogOnPlaceStartAir2StepsLStart_VKQOV                                           5
# ...                                                                          ...
# walk2StepsLstart_WQPMNHYS                                                      8
# walk2StepsLstart_WTQPMZYS                                                      7
# walk2StepsLstart_VWZQPMDHSS                                                    9
# walk2StepsLstart_WTQPMHSV                                                      6
# walk2StepsLstart_VWQPMDHSAG@                                                  10
# walk2StepsLstart_WTQPMZV                                                       6
# walk2StepsLstart_WQPMZYV                                                       6
# walk2StepsLstart_VXQPMDZS                                                      7
# walk2StepsLstart_VXQPMZSS                                                      7
# walk2StepsLstart_WTQPMJZYS                                                     8
# walk2StepsLstart_WQPMCHSS                                                      8
# walk2StepsLstart_VWQPMZS                                                       7
# walk2StepsLstart_VWOQPMDZS                                                     8
# walk2StepsLstart_UWQPMLHYVV                                                    8
# walk2StepsLstart_UWZQPMNHHYSA                                                 11
# walkBackwards2StepsRstart_QZRVAKMH                                             7
# walkBackwards2StepsRstart_WVMIQKMDHX                                           9
# walkBackwards2StepsRstart_QGZWVPQKDZX                                         10
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                       12
# walkBackwards2StepsRstart_FHWVJKKJAZ                                           9
# walkBackwards2StepsRstart_IXWVDKJGX                                            8
# walkBackwards2StepsRstart_OZUVKJMBHX                                           9
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                    13
# walkBackwards2StepsRstart_BOZWVDKJG                                            8
# walkBackwards2StepsRstart_OZWVJKJGG                                            8
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                      13
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                        10
# walkBackwards2StepsRstart_GZUDBKQNGZ                                           9
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                          9
# walkBackwards2StepsRstart_PHZWVDKNGGX                                         10
#
#                                             elbowToKnee1RepsLelbowStart_QPOPVWV@  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                             6
# elbowToKnee1RepsLelbowStart_QPQWWV                                             4
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                           3
# elbowToKnee1RepsLelbowStart_QPIRWV                                             4
# elbowToKnee1RepsLelbowStart_QO@WUVD                                            5
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                           5
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                          8
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                           7
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                           0
# elbowToKnee1RepsLelbowStart_QPQBWV                                             4
# elbowToKnee1RepsLelbowStart_QPQWUV                                             5
# elbowToKnee1RepsLelbowStart_BQOWVG                                             5
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                           4
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                          5
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                        7
# elbowToKnee1RepsLelbowStart_QPPMVWV                                            3
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                           3
# elbowToKnee1RepsLelbowStart_QPQAWV                                             4
# elbowToKnee1RepsLelbowStart_QOITUVT                                            5
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                           6
# elbowToKnee1RepsLelbowStart_QONEVV                                             5
# elbowToKnee1RepsLelbowStart_QPUWV                                              4
# elbowToKnee1RepsLelbowStart_QOWV                                               4
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                          5
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                        7
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                          7
# elbowToKnee1RepsLelbowStart_QPWUV                                              5
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                        8
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                         7
# jogOnPlaceStartAir2StepsLStart_VKQOV                                           7
# ...                                                                          ...
# walk2StepsLstart_WQPMNHYS                                                      7
# walk2StepsLstart_WTQPMZYS                                                      7
# walk2StepsLstart_VWZQPMDHSS                                                    9
# walk2StepsLstart_WTQPMHSV                                                      7
# walk2StepsLstart_VWQPMDHSAG@                                                   8
# walk2StepsLstart_WTQPMZV                                                       6
# walk2StepsLstart_WQPMZYV                                                       6
# walk2StepsLstart_VXQPMDZS                                                      7
# walk2StepsLstart_VXQPMZSS                                                      7
# walk2StepsLstart_WTQPMJZYS                                                     8
# walk2StepsLstart_WQPMCHSS                                                      7
# walk2StepsLstart_VWQPMZS                                                       7
# walk2StepsLstart_VWOQPMDZS                                                     7
# walk2StepsLstart_UWQPMLHYVV                                                    7
# walk2StepsLstart_UWZQPMNHHYSA                                                 10
# walkBackwards2StepsRstart_QZRVAKMH                                             7
# walkBackwards2StepsRstart_WVMIQKMDHX                                          10
# walkBackwards2StepsRstart_QGZWVPQKDZX                                          9
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                       10
# walkBackwards2StepsRstart_FHWVJKKJAZ                                          10
# walkBackwards2StepsRstart_IXWVDKJGX                                            9
# walkBackwards2StepsRstart_OZUVKJMBHX                                          10
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                    15
# walkBackwards2StepsRstart_BOZWVDKJG                                            8
# walkBackwards2StepsRstart_OZWVJKJGG                                            9
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                      12
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                        10
# walkBackwards2StepsRstart_GZUDBKQNGZ                                          10
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                          9
# walkBackwards2StepsRstart_PHZWVDKNGGX                                         10
#
#                                             elbowToKnee1RepsLelbowStart_QPQBWV  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                           4
# elbowToKnee1RepsLelbowStart_QPQWWV                                           1
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                         4
# elbowToKnee1RepsLelbowStart_QPIRWV                                           2
# elbowToKnee1RepsLelbowStart_QO@WUVD                                          5
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                         4
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                        7
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                         6
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                         4
# elbowToKnee1RepsLelbowStart_QPQBWV                                           0
# elbowToKnee1RepsLelbowStart_QPQWUV                                           2
# elbowToKnee1RepsLelbowStart_BQOWVG                                           4
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                         3
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                        6
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                      7
# elbowToKnee1RepsLelbowStart_QPPMVWV                                          3
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                         2
# ...
# walkBackwards2StepsRstart_GZUDBKQNGZ                                             9
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                            7
# walkBackwards2StepsRstart_PHZWVDKNGGX                                            9
#
#                                             walkBackwards2StepsRstart_GZUDBKQNGZ  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                             9
# elbowToKnee1RepsLelbowStart_QPQWWV                                             9
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                          10
# elbowToKnee1RepsLelbowStart_QPIRWV                                            10
# elbowToKnee1RepsLelbowStart_QO@WUVD                                           10
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                          10
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                         10
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                           9
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                          10
# elbowToKnee1RepsLelbowStart_QPQBWV                                             9
# elbowToKnee1RepsLelbowStart_QPQWUV                                             9
# elbowToKnee1RepsLelbowStart_BQOWVG                                             9
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                          10
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                         10
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                       10
# elbowToKnee1RepsLelbowStart_QPPMVWV                                           10
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                           9
# elbowToKnee1RepsLelbowStart_QPQAWV                                             9
# elbowToKnee1RepsLelbowStart_QOITUVT                                           10
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                          10
# elbowToKnee1RepsLelbowStart_QONEVV                                            10
# elbowToKnee1RepsLelbowStart_QPUWV                                              9
# elbowToKnee1RepsLelbowStart_QOWV                                               9
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                         10
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                       11
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                          9
# elbowToKnee1RepsLelbowStart_QPWUV                                             10
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                        9
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                         9
# jogOnPlaceStartAir2StepsLStart_VKQOV                                           8
# ...                                                                          ...
# walk2StepsLstart_WQPMNHYS                                                     10
# walk2StepsLstart_WTQPMZYS                                                     10
# walk2StepsLstart_VWZQPMDHSS                                                   10
# walk2StepsLstart_WTQPMHSV                                                     10
# walk2StepsLstart_VWQPMDHSAG@                                                  10
# walk2StepsLstart_WTQPMZV                                                       9
# walk2StepsLstart_WQPMZYV                                                      10
# walk2StepsLstart_VXQPMDZS                                                     10
# walk2StepsLstart_VXQPMZSS                                                     10
# walk2StepsLstart_WTQPMJZYS                                                    10
# walk2StepsLstart_WQPMCHSS                                                     10
# walk2StepsLstart_VWQPMZS                                                       9
# walk2StepsLstart_VWOQPMDZS                                                    10
# walk2StepsLstart_UWQPMLHYVV                                                   10
# walk2StepsLstart_UWZQPMNHHYSA                                                 11
# walkBackwards2StepsRstart_QZRVAKMH                                             8
# walkBackwards2StepsRstart_WVMIQKMDHX                                           9
# walkBackwards2StepsRstart_QGZWVPQKDZX                                          8
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                        6
# walkBackwards2StepsRstart_FHWVJKKJAZ                                           8
# walkBackwards2StepsRstart_IXWVDKJGX                                            8
# walkBackwards2StepsRstart_OZUVKJMBHX                                           8
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                    10
# walkBackwards2StepsRstart_BOZWVDKJG                                            8
# walkBackwards2StepsRstart_OZWVJKJGG                                            7
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                       7
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                         9
# walkBackwards2StepsRstart_GZUDBKQNGZ                                           0
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                          8
# walkBackwards2StepsRstart_PHZWVDKNGGX                                          8
#
#                                             walkBackwards2StepsRstart_QGZWVPQKKDZ  \
# elbowToKnee1RepsLelbowStart_OIKTWV                                             10
# elbowToKnee1RepsLelbowStart_QPQWWV                                              8
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                           10
# elbowToKnee1RepsLelbowStart_QPIRWV                                              9
# elbowToKnee1RepsLelbowStart_QO@WUVD                                             8
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                           10
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                          10
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                            9
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                            9
# elbowToKnee1RepsLelbowStart_QPQBWV                                              8
# elbowToKnee1RepsLelbowStart_QPQWUV                                              8
# elbowToKnee1RepsLelbowStart_BQOWVG                                              9
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                            9
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                          10
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                        11
# elbowToKnee1RepsLelbowStart_QPPMVWV                                             9
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                            9
# elbowToKnee1RepsLelbowStart_QPQAWV                                              8
# elbowToKnee1RepsLelbowStart_QOITUVT                                            10
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                            9
# elbowToKnee1RepsLelbowStart_QONEVV                                              9
# elbowToKnee1RepsLelbowStart_QPUWV                                               8
# elbowToKnee1RepsLelbowStart_QOWV                                                8
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                          10
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                        10
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                          11
# elbowToKnee1RepsLelbowStart_QPWUV                                               9
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                        10
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                          8
# jogOnPlaceStartAir2StepsLStart_VKQOV                                            9
# ...                                                                           ...
# walk2StepsLstart_WQPMNHYS                                                       9
# walk2StepsLstart_WTQPMZYS                                                      10
# walk2StepsLstart_VWZQPMDHSS                                                     9
# walk2StepsLstart_WTQPMHSV                                                      10
# walk2StepsLstart_VWQPMDHSAG@                                                   11
# walk2StepsLstart_WTQPMZV                                                        9
# walk2StepsLstart_WQPMZYV                                                        9
# walk2StepsLstart_VXQPMDZS                                                       8
# walk2StepsLstart_VXQPMZSS                                                      10
# walk2StepsLstart_WTQPMJZYS                                                     10
# walk2StepsLstart_WQPMCHSS                                                       9
# walk2StepsLstart_VWQPMZS                                                        9
# walk2StepsLstart_VWOQPMDZS                                                      8
# walk2StepsLstart_UWQPMLHYVV                                                    10
# walk2StepsLstart_UWZQPMNHHYSA                                                  11
# walkBackwards2StepsRstart_QZRVAKMH                                              7
# walkBackwards2StepsRstart_WVMIQKMDHX                                            8
# walkBackwards2StepsRstart_QGZWVPQKDZX                                           2
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                         6
# walkBackwards2StepsRstart_FHWVJKKJAZ                                            7
# walkBackwards2StepsRstart_IXWVDKJGX                                             8
# walkBackwards2StepsRstart_OZUVKJMBHX                                            9
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                     11
# walkBackwards2StepsRstart_BOZWVDKJG                                             7
# walkBackwards2StepsRstart_OZWVJKJGG                                             7
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                       10
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                          7
# walkBackwards2StepsRstart_GZUDBKQNGZ                                            8
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                           0
# walkBackwards2StepsRstart_PHZWVDKNGGX                                           8
#
#                                             walkBackwards2StepsRstart_PHZWVDKNGGX
# elbowToKnee1RepsLelbowStart_OIKTWV                                             10
# elbowToKnee1RepsLelbowStart_QPQWWV                                              9
# elbowToKnee1RepsLelbowStart_QPO@AVWV                                           10
# elbowToKnee1RepsLelbowStart_QPIRWV                                              9
# elbowToKnee1RepsLelbowStart_QO@WUVD                                             9
# elbowToKnee1RepsLelbowStart_QPIN@RWV                                           11
# elbowToKnee1RepsLelbowStart_@AQOIUVDN                                          10
# elbowToKnee1RepsLelbowStart_AAQQOKBV                                           10
# elbowToKnee1RepsLelbowStart_QPOPVWV@                                           10
# elbowToKnee1RepsLelbowStart_QPQBWV                                              9
# elbowToKnee1RepsLelbowStart_QPQWUV                                             10
# elbowToKnee1RepsLelbowStart_BQOWVG                                              8
# elbowToKnee1RepsLelbowStart_QPQJ@VWV                                           10
# elbowToKnee1RepsLelbowStart_QPOK@RVUV                                          11
# elbowToKnee1RepsLelbowStart_AAQOBBTVWVK                                        11
# elbowToKnee1RepsLelbowStart_QPPMVWV                                            10
# elbowToKnee1RepsLelbowStart_QPQPBVWV                                           10
# elbowToKnee1RepsLelbowStart_QPQAWV                                              9
# elbowToKnee1RepsLelbowStart_QOITUVT                                            11
# elbowToKnee1RepsLelbowStart_OOLTWVMK                                            9
# elbowToKnee1RepsLelbowStart_QONEVV                                             10
# elbowToKnee1RepsLelbowStart_QPUWV                                               9
# elbowToKnee1RepsLelbowStart_QOWV                                                9
# elbowToKnee1RepsLelbowStart_AQPQOLWVV                                          11
# elbowToKnee1RepsLelbowStart_QPQKKSVUVAI                                        11
# elbowToKnee1RepsLelbowStart_KAQJBBVUV                                          11
# elbowToKnee1RepsLelbowStart_QPWUV                                              10
# jogOnPlaceStartAir2StepsLStart_UVYGWPHE                                        10
# jogOnPlaceStartAir2StepsLStart_VGWNPNW                                          9
# jogOnPlaceStartAir2StepsLStart_VKQOV                                            9
# ...                                                                           ...
# walk2StepsLstart_WQPMNHYS                                                       9
# walk2StepsLstart_WTQPMZYS                                                      10
# walk2StepsLstart_VWZQPMDHSS                                                    10
# walk2StepsLstart_WTQPMHSV                                                      10
# walk2StepsLstart_VWQPMDHSAG@                                                    9
# walk2StepsLstart_WTQPMZV                                                       10
# walk2StepsLstart_WQPMZYV                                                       10
# walk2StepsLstart_VXQPMDZS                                                      10
# walk2StepsLstart_VXQPMZSS                                                      11
# walk2StepsLstart_WTQPMJZYS                                                     11
# walk2StepsLstart_WQPMCHSS                                                      10
# walk2StepsLstart_VWQPMZS                                                       10
# walk2StepsLstart_VWOQPMDZS                                                     10
# walk2StepsLstart_UWQPMLHYVV                                                    11
# walk2StepsLstart_UWZQPMNHHYSA                                                  11
# walkBackwards2StepsRstart_QZRVAKMH                                              8
# walkBackwards2StepsRstart_WVMIQKMDHX                                            9
# walkBackwards2StepsRstart_QGZWVPQKDZX                                           7
# walkBackwards2StepsRstart_QPZWVDPKKQNGZ                                         7
# walkBackwards2StepsRstart_FHWVJKKJAZ                                            7
# walkBackwards2StepsRstart_IXWVDKJGX                                             5
# walkBackwards2StepsRstart_OZUVKJMBHX                                            8
# walkBackwards2StepsRstart_HFHZWVDJOKBQEGGZ                                      8
# walkBackwards2StepsRstart_BOZWVDKJG                                             5
# walkBackwards2StepsRstart_OZWVJKJGG                                             5
# walkBackwards2StepsRstart_@IPZWUVABKQNGY                                        9
# walkBackwards2StepsRstart_BKPZWVJOQKMZ                                          9
# walkBackwards2StepsRstart_GZUDBKQNGZ                                            8
# walkBackwards2StepsRstart_QGZWVPQKKDZ                                           8
# walkBackwards2StepsRstart_PHZWVDKNGGX                                           0
#
# [216 rows x 216 columns]
